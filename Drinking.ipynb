# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('F:/Pycharm/Data Analytics/Drinking/drinks.csv')
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
df.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# dtype: int64

# %%
df1 = df.groupby ('country', as_index=False, sort=True)['beer_servings'].sum()
df1 = df1.sort_values('beer_servings', ascending=False)
df1.head()
# Out:
#             country  beer_servings
# 118         Namibia            376
# 45   Czech Republic            361
# 61            Gabon            347
# 64          Germany            346
# 97        Lithuania            343

# %%
df2 = df.groupby('country', as_index=False, sort=True)['spirit_servings'].sum()
df2 = df2.sort_values('spirit_servings', ascending=False)
df2.head()
# Out:
#                 country  spirit_servings
# 67              Grenada              438
# 15              Belarus              373
# 72                Haiti              326
# 141  Russian Federation              326
# 161           St. Lucia              315

# %%
df3 = df.groupby('country', as_index=False, sort=True)['wine_servings'].sum()
df3 = df3.sort_values('wine_servings', ascending=False)
df3.head()
# Out:
#          country  wine_servings
# 60        France            370
# 138     Portugal            339
# 3        Andorra            312
# 167  Switzerland            280
# 47       Denmark            278

# %%
df4 = df.groupby('country', as_index=False, sort=True)['total_litres_of_pure_alcohol'].sum()
df4 = df4.sort_values('total_litres_of_pure_alcohol', ascending=False)
df4.head()
# Out:
#       country  total_litres_of_pure_alcohol
# 15    Belarus                          14.4
# 97  Lithuania                          12.9
# 3     Andorra                          12.4
# 67    Grenada                          11.9
# 60     France                          11.8

# %%
le = pd.read_csv('F:/Pycharm/Data Analytics/Drinking/lifeexpectancy-verbose.csv')

keep_col = ['GhoDisplay', 'RegionDisplay', 'WorldBankIncomeGroupDisplay', 'CountryDisplay', 'SexDisplay',
            'YearDisplay', 'DisplayValue']
le2 = le[keep_col]
le2.to_csv('lifeexpectancy.csv')
le2
# Out:
#                                            GhoDisplay          RegionDisplay  \
# 0                    Life expectancy at birth (years)               Americas
# 1     Healthy life expectancy (HALE) at birth (years)                 Europe
# 2                    Life expectancy at birth (years)  Eastern Mediterranean
# 3                    Life expectancy at birth (years)                 Africa
# 4                   Life expectancy at age 60 (years)        South_East Asia
# ...                                               ...                    ...
# 6403                 Life expectancy at birth (years)  Eastern Mediterranean
# 6404                Life expectancy at age 60 (years)        Western Pacific
# 6405                 Life expectancy at birth (years)                 Africa
# 6406  Healthy life expectancy (HALE) at birth (years)                 Europe
# 6407                 Life expectancy at birth (years)                 Europe
#
# ...

# %%
le2.head()
# Out:
#                                         GhoDisplay          RegionDisplay  \
# 0                 Life expectancy at birth (years)               Americas
# 1  Healthy life expectancy (HALE) at birth (years)                 Europe
# 2                 Life expectancy at birth (years)  Eastern Mediterranean
# 3                 Life expectancy at birth (years)                 Africa
# 4                Life expectancy at age 60 (years)        South_East Asia
#
#   WorldBankIncomeGroupDisplay CountryDisplay  SexDisplay  YearDisplay  \
# 0         Lower_middle_income      Nicaragua        Male         1990
# 1                 High_income        Ireland        Male         2012
# 2                  Low_income          Yemen  Both sexes         2000
# 3         Lower_middle_income        Nigeria      Female         2000
# 4         Lower_middle_income       Thailand      Female         1990
#
#    DisplayValue
# 0            68
# 1            69
# 2            61
# 3            48
# ...

# %%
le2.tail()
# Out:
#                                            GhoDisplay          RegionDisplay  \
# 6403                 Life expectancy at birth (years)  Eastern Mediterranean
# 6404                Life expectancy at age 60 (years)        Western Pacific
# 6405                 Life expectancy at birth (years)                 Africa
# 6406  Healthy life expectancy (HALE) at birth (years)                 Europe
# 6407                 Life expectancy at birth (years)                 Europe
#
#      WorldBankIncomeGroupDisplay CountryDisplay  SexDisplay  YearDisplay  \
# 6403         Lower_middle_income        Morocco  Both sexes         2000
# 6404         Upper_middle_income          Palau  Both sexes         1990
# 6405                  Low_income   Burkina Faso      Female         1990
# 6406         Lower_middle_income        Albania        Male         2012
# 6407                         NaN        Armenia  Both sexes         2013
#
#       DisplayValue
# 6403            68
# 6404            16
# ...

# %%
le2 = le2.groupby(['CountryDisplay'],as_index=False)['DisplayValue'].sum()
le2 = le2.sort_values('DisplayValue', ascending=False)
le2.head()
# Out:
#     CountryDisplay  DisplayValue
# 85           Japan          1949
# 147     San Marino          1924
# 154      Singapore          1904
# 167    Switzerland          1900
# 111         Monaco          1899

# %%
le2 = le2[:]
plt.figure(figsize=(40, 40))
sns.set_style('darkgrid')
plt.xticks(rotation=45, ha='right', fontsize=11)
plt.xlabel('Name of Country', fontsize=30)
plt.ylabel('Life Expectancy Age', fontsize=30)
p = sns.barplot(x='CountryDisplay', y='DisplayValue', data=le2)
p.set(xlabel='Name of Country', ylabel='Life Expectancy Age')
p.set_title('Life Expectancy Per Country')
# Out:
# Text(0.5, 1.0, 'Life Expectancy Per Country')

# %%
le3 = le.groupby(['WorldBankIncomeGroupDisplay'], as_index=False)['DisplayValue'].sum()
le3 = le3.sort_values('DisplayValue', ascending=False)
le3.head()
# Out:
#   WorldBankIncomeGroupDisplay  DisplayValue
# 0                 High_income         76220
# 2         Lower_middle_income         67726
# 3         Upper_middle_income         62229
# 1                  Low_income         49530

# %%
le3 = le3[:]
plt.figure(figsize=(40,40))
plt.xticks(rotation=45, ha='right', fontsize=40)
p = sns.barplot(x='WorldBankIncomeGroupDisplay', y='DisplayValue', data=le3)
p.set(xlabel='Region Area', ylabel='Life Expectancy Age')
p.set_title('Life Expectancy Per Region')
# Out:
# Text(0.5, 1.0, 'Life Expectancy Per Region')

# %%
le4 = le.groupby(['RegionDisplay'], as_index=False)['DisplayValue'].sum()
le4 = le4.sort_values('DisplayValue', ascending=False)
le4.head()
# Out:
#            RegionDisplay  DisplayValue
# 3                 Europe         92631
# 0                 Africa         60499
# 1               Americas         59479
# 5        Western Pacific         44400
# 2  Eastern Mediterranean         34566

# %%
le4 = le4[:]
plt.figure(figsize=(20, 20))
plt.xticks(rotation=45, ha='right', fontsize=40)
p = sns.barplot(x='RegionDisplay', y='DisplayValue', data=le4)
p.set(xlabel='Region Area', ylabel='Life Expectancy Age')
p.set_title('Life Expectancy Per Region')
# Out:
# Text(0.5, 1.0, 'Life Expectancy Per Region')

# %%
df1 = df1[:]
plt.figure(figsize=(40, 40))
sns.set_style('darkgrid')
plt.xticks(rotation=45, ha='right', fontsize=11)
plt.xlabel('Country', fontsize=30)
plt.ylabel('Beer Servings ', fontsize=30)
p = sns.barplot(x='country', y='beer_servings', data=df1)
p.set(xlabel='Name of Country', ylabel='Beer Servings')
p.set_title('What country drinks the most beer per serving?')
# Out:
# Text(0.5, 1.0, 'What country drinks the most beer per serving?')

# %%
df2 = df2[:]
plt.figure(figsize=(40, 40))
sns.set_style('darkgrid')
plt.xticks(rotation=45, ha='right', fontsize=11)
plt.xlabel('Country', fontsize=30)
plt.ylabel('Spirit Servings ', fontsize=30)
p = sns.barplot(x='country', y='spirit_servings', data=df2)
p.set(xlabel='Name of Country', ylabel='Spirit Servings')
p.set_title('What country drinks the most spirits per serving?')
# Out:
# Text(0.5, 1.0, 'What country drinks the most spirits per serving?')

# %%
df3 = df3[:]
plt.figure(figsize=(40, 40))
sns.set_style('darkgrid')
plt.xticks(rotation=45, ha='right', fontsize=11)
plt.xlabel('Country', fontsize=30)
plt.ylabel('Wine Servings ', fontsize=30)
p = sns.barplot(x='country', y='wine_servings', data=df3)
p.set(xlabel='Name of Country', ylabel='Wine Servings')
p.set_title('What country drinks the most wine per serving?')
# Out:
# Text(0.5, 1.0, 'What country drinks the most wine per serving?')

# %%
df4 = df4[:]
plt.figure(figsize=(40, 40))
sns.set_style('darkgrid')
plt.xticks(rotation=45, ha='right', fontsize=11)
plt.xlabel('Country', fontsize=30)
plt.ylabel('Total Litres Of Pure Alcohol Drank ', fontsize=30)
p = sns.barplot(x='country', y='total_litres_of_pure_alcohol', data=df4)
p.set(xlabel='Name of Country', ylabel='Litres of Alcohol')
p.set_title('What country drinks the most Litres of Pure Alcohol?')
# Out:
# Text(0.5, 1.0, 'What country drinks the most Litres of Pure Alcohol?')
